# %% [markdown]
# # Smarte und interaktive Kurzskripte (smartiS)
#
#
# [P. Kersten](https://www.hshl.de/personen/prof-dr-ing-peter-kersten), [J. Jeschonowski](https://www.xing.com/profile/Jule_Jeschonowski/cv), [L.P. Kamegne-Kamdem](https://www.linkedin.com/in/leger-paco-kamegne-kamdem-07ba39184/), [N.B. Neathery](https://www.linkedin.com/in/noel-neathery-6371561a6/) und D.M. Weis
#
# [Hochschule Hamm-Lippstadt](https://www.hshl.de), Marker Allee 76–78, D-59063 Hamm

# %% [markdown]
# ![Physiks_PP_41_110_170.PNG](attachment:Physiks_PP_41_110_170.PNG)
# _____________________________________________________________________________________________________
#
# # Intro für die smartiS
#
# Hallo liebe Physiklernende,
#
# ihr befindet euch im "Einführungssmarti" (oder kurz: Intro). Der Begriff **smartiS** steht für smarte und interaktive Skripte. Die **smartiS** die ihr hier findet, sollen euch beim Verständnis von physikalischen Gesetzen unterstützen.
#
# ## Wie sind die **smartiS** aufgebaut?
#
# Jedes Smarti beginnt mit einer Überschrift, der Autorender, einer Aufzählung, sowie einem Verweis auf die Hochschule Hamm-Lippstadt.
#
# Daraufhin folgt die Überschrift des jeweiligen physikalischen Themas, das vom smarti behandelt wird, sowie das Inhaltsverzeichnis des smartis.
#
# smartiS beinhalten immer Erklärungstexte und Codezeilen, die das smarti interaktiv machen. Außerdem gibt es hier Bilder, Tabellen, Buttons und Diagramme.
#
# **<span style="color:#296EAA">Was für euch besonders interessant sein dürfte:</span>** Um euer Wissen zu überprüfen gibt es so genannte "Knowledge Checks". Das sind Aufgaben mit denen ihr euch selber überprüfen und auf Klausuren vorbereiten könnt.
#
# Am Ende der smartiS gibt es eine Danksagung inklusive Benennung der Lizenz unter der das smarti veröffentlicht ist.
#
# Die smartiS wurden im Rahmen des Programms [Fellowships für Innovationen in der digitalen Hochschullehre](https://www.stifterverband.org/digital-lehrfellows-nrw) des Ministeriums für Kultur und Wissenschaft des Landes Nordrhein-Westfalen und des Stifterverbandes entwickelt. Weitere Details finden sich im [Projektantrag](https://www.stifterverband.org/digital-lehrfellows-nrw/2019/temmen_kersten).

# %% [markdown]
# # Wie setze ich die smartiS am besten ein?¶
#
# Um die SmartiS nutzen zu können ist **keine** Installation von Software nötig - alles läuft online.
#
# Die von uns mithilfe von [Jupyter Notebook](https://jupyter.org) erstellten smartis könnt ihr am besten mit der Web-Applikation [nbviewer](https://nbviewer.jupyter.org) aufrufen und ansehen.
#
# Dazu geht ihr auf https://nbviewer.jupyter.org und gebt dort in der Leiste **PeterAKersten/physics** ein, wie auf folgendem Bild zu sehen:
# _____________________________________________________________________________________________________
#
# ![Bildschirmfoto%202020-11-03%20um%2010.57.05.png](attachment:Bildschirmfoto%202020-11-03%20um%2010.57.05.png)
#
# _____________________________________________________________________________________________________
#
# Das ganze bestätigt ihr mit Enter oder Klick auf "Go!"

# %% [markdown]
# Im Anschluss seht ihr ein Verzeichnis, das ungefähr so aussieht:
#
# _____________________________________________________________________________________________________
#
# ![Bildschirmfoto%202020-11-03%20um%2011.02.04.png](attachment:Bildschirmfoto%202020-11-03%20um%2011.02.04.png)
#
#
# _____________________________________________________________________________________________________
#
# Dort wählt ihr das gewünschte Smarti aus, mit dem ihr euch beschäftigen wollt.
#
# Da unsere Skripte interaktiv sind, sollen euch hier individuelle Lösungen geboten werden. Um diese individuellen Lösungen zu ermöglichen müsst ihr die smartis im Webservice mybinder starten.
#
# Hierfür klickt ihr im nbviewer oben in der Befehlszeile auf das Symbol mit den 3 Ringen "Execute on mybinder":
#
# ![Bildschirmfoto%202020-11-03%20um%2011.04.51.png](attachment:Bildschirmfoto%202020-11-03%20um%2011.04.51.png)

# %% [markdown]
# Ihr werdet auf eine andere Website weitergeleitet, die so aussehen sollte:
#
# _____________________________________________________________________________________________________
#
# ![Bildschirmfoto%202020-11-03%20um%2011.06.33.png](attachment:Bildschirmfoto%202020-11-03%20um%2011.06.33.png)
#
# _____________________________________________________________________________________________________
#
# Es dauert ein wenig bis das Skript vollständig geladen ist.

# %% [markdown]
# Nun befindet ihr euch im Notebook des Smartis. Das Smarti lässt sich über die Doppelpfeile in der Befehlsleiste starten.
#
# _____________________________________________________________________________________________________
#
# ![Bildschirmfoto%202020-11-03%20um%2011.08.12.png](attachment:Bildschirmfoto%202020-11-03%20um%2011.08.12.png)
#
#
# _____________________________________________________________________________________________________

# %% [markdown]
# Im nächsten Fenster wählt ihr einfach den roten Button "Restart and Run All Cells" aus.
#
# _____________________________________________________________________________________________________
#
# ![Bildschirmfoto%202020-11-03%20um%2011.10.53.png](attachment:Bildschirmfoto%202020-11-03%20um%2011.10.53.png)
#
#
#
# _____________________________________________________________________________________________________

# %% [markdown]
# Daraufhin solltet ihr keinen Code mehr sehen, sondern lediglich Erklärungstext, Bilder, Diagramme und Co.
# Außerdem gibt es einen Button auf dem "Quellcode anzeigen" steht. Diesen Button braucht ihr nur, wenn ihr ausdrücklich dazu aufgefordert werden bzw. wenn euch interessiert, was hinter den interaktiven Teilen der Smartis steckt.
#
# Nun könnt ihr nach Lust und Laune die verschiedenen Schieberegler und Buttons verwenden, um individuell und interaktiv eure Aufgaben zu lösen. Selbst den Quellcode könnt ihr verändern und den jeweiligen Abschnitt mit einem Klick auf die Run Taste erneut ausführen.
#
# _____________________________________________________________________________________________________
#
# ![Bildschirmfoto%202020-11-10%20um%2009.30.52.png](attachment:Bildschirmfoto%202020-11-10%20um%2009.30.52.png)
#
# _____________________________________________________________________________________________________

# %% [markdown]
# **Optional und definitiv keine Pflicht**: Sollte euch eine weitere Nutzung bzw. auch die Programmierung der Skripte mit Python interessieren, schaut euch gerne die Installation von Jupyter an.

# %% [markdown]
# # Installationen von Jupyter (Optional und definitiv keine Pflicht)
#
# **Windows**
#
# Für die lokale Installation von Jupyter Notebook findet ihr [hier](https://www.tu-ilmenau.de/neurob/teaching/python-installation/) eine Anleitung sowie weitere nützliche Informationen.
#
#
# **MacOS**
#
# Für die lokale Installation von Jupyter Notebook nutzt ihr am besten den Anaconda-Navigator.
# Die Anleitung sowie einen Link zur Installationssoftware findet ihr [hier](https://docs.anaconda.com/anaconda/install/mac-os/).
#
# Der Anaconda-Navigator beinhaltet weit mehr als nur Jupyter Notebook und Python. Jedoch ist dies die einfachste Variante Jupyter Notebook lokal auf macOS zu verwenden. Nach erfolgreicher Installation könnt ihr nach starten des Anaconda-Navigators Jupyter Notebook launchen.
#
# **Linux**
#
# Auch für Linux Nutzer bietet sich die Nutzung des Anaconda-Navigators an. Den Link dazu findet ihr [hier](https://docs.anaconda.com/anaconda/install/).

# %% [markdown]
# # Wie fandet ihr dieses (noch nicht ganz so smarte und interaktive) smarti?
#
# [Lasst uns gerne Feedback da!](https://pingo.coactum.de/390556) Viel Spaß wünscht das smartiS Team :-)

# %% [markdown]
# Oktober 2020 (CC BY-SA 4.0)
